# %% [markdown]
# # STEP 1: ADD REQUIRED LIBRARIES

# %%
import pandas as pd
import numpy as np
import nltk
import timeit
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import sklearn.metrics
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score

# %% [markdown]
# # STEP 2: SET RANDOM SEED

# %%
# This is used to reproduce the same result every time if the script is kept consistent.
# Otherwise, each run will produce different results. The seed can be set to any number.
np.random.seed(500)

# %% [markdown]
# # STEP 3: LOAD TWITTER DATASET

# %%
# STEP 3: ADD CORPUS
print("Loading data...")
dataset = pd.read_csv("Datasets/Twitter.csv", encoding='latin-1', names=["label", "id", "date", "flag", "user", "text"])
dataset = dataset.drop(dataset.index[0])
print("Data successfully loaded!")
print(dataset)


# NOTE: The code below was used to reuce the source dataset (Twitter_Source.csv)
# into a reduced set of 50,000 records (25,000 positive, 25,000 negative). The
# purpose for doing so is to match the number of records in IMDB dataset.

#dataset = dataset.sample(frac=1).reset_index(drop=True)
#print(dataset)
#df_pos = dataset[(dataset.label == 0)].head(25000)
#print(df_pos)
#df_neg = dataset[(dataset.label == 4)].head(25000)
#print(df_neg)
#frames = [df_pos, df_neg]
#data_reduced = pd.concat(frames)
#print(data_reduced)
#data_reduced.to_csv("Twitter_Reduced.csv", encoding='utf-8', index=False)
# Out:
# Loading data...
# Data successfully loaded!
#       label          id                          date      flag  \
# 1         0  2049279662  Fri Jun 05 16:36:21 PDT 2009  NO_QUERY
# 2         0  2204003722  Wed Jun 17 01:04:33 PDT 2009  NO_QUERY
# 3         0  2186271634  Mon Jun 15 18:36:03 PDT 2009  NO_QUERY
# 4         0  1678353782  Sat May 02 06:25:56 PDT 2009  NO_QUERY
# 5         0  1695759054  Mon May 04 06:53:05 PDT 2009  NO_QUERY
# ...     ...         ...                           ...       ...
# 49996     4  1834175935  Mon May 18 01:55:22 PDT 2009  NO_QUERY
# 49997     4  1982199141  Sun May 31 10:43:39 PDT 2009  NO_QUERY
# 49998     4  1999647354  Mon Jun 01 20:34:49 PDT 2009  NO_QUERY
# 49999     4  1988905306  Sun May 31 23:43:41 PDT 2009  NO_QUERY
# 50000     4  1882355493  Fri May 22 06:43:20 PDT 2009  NO_QUERY
#
#                   user                                               text
# 1             ccccourt                     My family is a bunch of hicks
# 2           nurulaulia                        oh gosh! what can i do now
# 3               Jamb0r  Facebook status: James can't get into his emai...
# 4             meganstk  Sniffling, and lonely. Great, just how I wante...
# 5           lachlanroy  @Bongchi i'll get there eventually, but it sti...
# ...                ...                                                ...
# 49996        LiliCosic  @loris_sl London is nice  Also Slovenia :p Wer...
# 49997  MileyIsAmazing1  I hope wins the two awards that she is nominat...
# 49998            Gen22                                    @FutureisClear
# 49999   anastasiawendy                    Spare my time with mom at home
# 50000        Citylady1  Morning all, just got off work (6:30 am) soooo...
#
# [50000 rows x 6 columns]

# %% [markdown]
# # STEP 4: DATA PROCESSING

# %%
# Step 4a: Remove blank rows if any.
print("\nStart of Data Pre-processing...")
print("- Removing blanks...")
dataset['text'].dropna(inplace=True)
print("- Blanks removed.")
# Out:
# Start of Data Pre-processing...
# - Removing blanks...
# - Blanks removed.

# %%
# Step 4b : Change all the text to lower case. 
print("- Converting to lowercase...")
dataset['text'] = [entry.lower() for entry in dataset['text']]
print("- Converted to lowercase.")
# Out:
# - Converting to lowercase...
# - Converted to lowercase.

# %%
# Step 4c: Tokenization to divide each entry in dataset into a set of words (unigram)
print("- Starting tokenization...")
dataset['text'] = [word_tokenize(entry) for entry in dataset['text']]
print("- Tokenization is complete")
print(dataset['text'])
print("- End of data pre-processing.")
print("\n***** Current View of Corpus *****\n")
print(dataset)
# Out:
# - Starting tokenization...
# - Tokenization is complete
# 1                    [my, family, is, a, bunch, of, hicks]
# 2                     [oh, gosh, !, what, can, i, do, now]
# 3        [facebook, status, :, james, ca, n't, get, int...
# 4        [sniffling, ,, and, lonely, ., great, ,, just,...
# 5        [@, bongchi, i, 'll, get, there, eventually, ,...
#                                ...
# 49996    [@, loris_sl, london, is, nice, also, slovenia...
# 49997    [i, hope, wins, the, two, awards, that, she, i...
# 49998                                   [@, futureisclear]
# 49999               [spare, my, time, with, mom, at, home]
# 50000    [morning, all, ,, just, got, off, work, (, 6:3...
# Name: text, Length: 50000, dtype: object
# - End of data pre-processing.
#
# ***** Current View of Corpus *****
#
#       label          id                          date      flag  \
# 1         0  2049279662  Fri Jun 05 16:36:21 PDT 2009  NO_QUERY
# 2         0  2204003722  Wed Jun 17 01:04:33 PDT 2009  NO_QUERY
# 3         0  2186271634  Mon Jun 15 18:36:03 PDT 2009  NO_QUERY
# 4         0  1678353782  Sat May 02 06:25:56 PDT 2009  NO_QUERY
# 5         0  1695759054  Mon May 04 06:53:05 PDT 2009  NO_QUERY
# ...     ...         ...                           ...       ...
# 49996     4  1834175935  Mon May 18 01:55:22 PDT 2009  NO_QUERY
# 49997     4  1982199141  Sun May 31 10:43:39 PDT 2009  NO_QUERY
# 49998     4  1999647354  Mon Jun 01 20:34:49 PDT 2009  NO_QUERY
# 49999     4  1988905306  Sun May 31 23:43:41 PDT 2009  NO_QUERY
# 50000     4  1882355493  Fri May 22 06:43:20 PDT 2009  NO_QUERY
#
#                   user                                               text
# 1             ccccourt              [my, family, is, a, bunch, of, hicks]
# 2           nurulaulia               [oh, gosh, !, what, can, i, do, now]
# 3               Jamb0r  [facebook, status, :, james, ca, n't, get, int...
# 4             meganstk  [sniffling, ,, and, lonely, ., great, ,, just,...
# 5           lachlanroy  [@, bongchi, i, 'll, get, there, eventually, ,...
# ...                ...                                                ...
# 49996        LiliCosic  [@, loris_sl, london, is, nice, also, slovenia...
# 49997  MileyIsAmazing1  [i, hope, wins, the, two, awards, that, she, i...
# 49998            Gen22                                 [@, futureisclear]
# 49999   anastasiawendy             [spare, my, time, with, mom, at, home]
# 50000        Citylady1  [morning, all, ,, just, got, off, work, (, 6:3...
#
# [50000 rows x 6 columns]

# %% [markdown]
# # STEP 5: PREPARE TRAIN & TEST DATASETS

# %%
print("- Splitting dataset (80% train, 20% test)...")
train_x, test_x, train_y, test_y = model_selection.train_test_split(dataset['text'], dataset['label'], test_size=0.2)
print("- Data splitting is complete.")
# Out:
# - Splitting dataset (80% train, 20% test)...
# - Data splitting is complete.

# %% [markdown]
# # STEP 6: DATA ENCODING

# %%
print("- Encoding data if necessary (i.e. categorical data converted to numerical values)...\n")
Encoder = LabelEncoder()
print("Original Train_Y: ", train_y)
train_y = Encoder.fit_transform(train_y)
print("New Train_Y:      ", train_y)
print("Original Test_Y:  ", test_y)
test_y = Encoder.fit_transform(test_y)
print("New Test_Y:       ", test_y)
print("\n- Data encoding is complete.")
# Out:
# - Encoding data if necessary (i.e. categorical data converted to numerical values)...
#
# Original Train_Y:  544      0
# 25471    4
# 29799    4
# 28699    4
# 18439    0
#         ..
# 19390    0
# 3791     0
# 41234    4
# 44866    4
# 17336    0
# Name: label, Length: 40000, dtype: object
# New Train_Y:       [0 1 1 ... 1 1 0]
# Original Test_Y:   26125    4
# 8563     0
# 43160    4
# 41936    4
# 8868     0
#         ..
# 37048    4
# 40067    4
# 33889    4
# 27836    4
# 1305     0
# Name: label, Length: 10000, dtype: object
# New Test_Y:        [1 0 1 ... 1 1 0]
#
# - Data encoding is complete.

# %% [markdown]
# # STEP 7: TF-IDF Feature Vectorization

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

def dummy_fun(doc):
    return doc

tfidf = TfidfVectorizer(
    analyzer='word',
    tokenizer=dummy_fun,
    preprocessor=dummy_fun,
    token_pattern=None)

tfidf.fit(dataset['text'])
tfidf.vocabulary_
# Out:
# {'my': 40382,
#  'family': 22207,
#  'is': 29723,
#  'a': 5328,
#  'bunch': 12432,
#  'of': 42402,
#  'hicks': 27338,
#  'oh': 42498,
#  'gosh': 25426,
#  '!': 0,
#  'what': 61792,
#  'can': 12979,
#  'i': 28413,
#  'do': 19139,
#  'now': 42027,
#  'facebook': 22043,
#  'status': 54017,
#  ':': 5137,
#  'james': 30249,
#  'ca': 12719,
#  "n't": 40541,
#  'get': 24737,
#  'into': 29528,
#  'his': 27503,
#  'email': 20804,
#  'account': 5670,
#  'well': 61637,
#  ',': 679,
#  'could': 16101,
#  'with': 62329,
#  'fresh': 23787,
#  'start': 53961,
#  '-': 687,
#  'the': 56574,
#  'old': 42649,
#  'one': 42794,
#  'was': 61247,
#  'getting..': 24759,
#  'sniffling': 52772,
#  'and': 7349,
#  'lonely': 35659,
#  '.': 808,
#  'great': 25662,
#  'just': 32044,
#  'how': 28042,
#  'wanted': 61190,
#  'to': 57730,
#  'spend': 53490,
#  'day': 17646,
#  'you': 63704,
#  '@': 5174,
#  'bongchi': 11319,
#  "'ll": 166,
#  'there': 56899,
#  'eventually': 21573,
#  'but': 12545,
#  'it': 29815,
#  'still': 54280,
#  'kinda': 33149,
#  'sucks': 54749,
#  'c4': 12709,
#  'so': 52835,
#  'freakin': 23688,
#  "'": 5,
#  'annoying': 7662,
#  '&': 4,
#  'gt': 25927,
#  ';': 5153,
#  '_': 5195,
#  'lt': 36082,
#  'duncjohnson': 19995,
#  'have': 26712,
#  'fun': 24051,
#  'in': 29056,
#  'japan': 30385,
#  'miss': 38829,
#  'everyone': 21602,
#  'already': 6910,
#  'been': 10049,
#  'trying': 58672,
#  'through': 57255,
#  'doctor': 19178,
#  'for': 23422,
#  'last': 34149,
#  'half': 26327,
#  'hour': 27993,
#  'very': 60428,
#  'irritating': 29720,
#  'theroser': 56975,
#  "'m": 172,
#  'bummed': 12412,
#  "'s": 239,
#  'no': 41705,
#  'crazy': 16349,
#  'moon': 39506,
#  'tour': 58188,
#  'dates': 17515,
#  '2': 3970,
#  'concerts': 15602,
#  'going': 25222,
#  'will': 62140,
#  'be': 9817,
#  'meet': 37861,
#  'amp': 7245,
#  'greets': 25731,
#  'kc': 32611,
#  'tulsa': 58765,
#  '?': 5173,
#  'photogwendy': 44692,
#  'easy': 20279,
#  'watch': 61280,
#  'road': 48719,
#  'when': 61860,
#  'parking': 43827,
#  'lot': 35841,
#  'want': 61184,
#  'some': 53013,
#  'cookies': 15884,
#  'raining': 47047,
#  'today': 57773,
#  'anyone': 7794,
#  'used': 59999,
#  'opera': 42969,
#  'unite': 59757,
#  'yet': 63591,
#  'tests': 56400,
#  'dadepo': 17090,
#  'yday': 63441,
#  'didnt': 18561,
#  'work': 62587,
#  'websitejeff': 61482,
#  'awww': 8983,
#  'r': 46804,
#  'not': 41940,
#  'ugly': 59453,
#  '(': 334,
#  'via': 60466,
#  'oneridewarrior': 42816,
#  ')': 335,
#  'see': 50663,
#  'say': 50173,
#  'something': 53046,
#  'nice': 41326,
#  'ignore': 28722,
#  'me': 37711,
#  '...': 817,
#  'babys': 9195,
#  'town': 58212,
#  'got': 25442,
#  'ta': 55625,
#  'pull': 46402,
#  'twelver': 58986,
#  'ready': 47405,
#  'go': 25144,
#  'back': 9225,
#  'home': 27706,
#  'watching': 61292,
#  '3': 4281,
#  'nieces': 41448,
#  'while': 61881,
#  '1': 3532,
#  'niece': 41447,
#  'gets': 24754,
#  'cast': 13393,
#  'put': 46533,
#  'on': 42771,
#  'she': 51307,
#  'broke': 12045,
#  'her': 27168,
#  'wrist': 62753,
#  'yesterday': 63579,
#  'jenlemonlime': 30806,
#  'why': 62021,
#  'study': 54585,
#  '.no': 1168,
#  'luck': 36107,
#  'uncleo': 59598,
#  'thought': 57202,
#  'u': 59358,
#  'luv': 36239,
#  'anymore': 7787,
#  'am': 7017,
#  'alone': 6880,
#  'this': 57107,
#  'week': 61540,
#  'jesse': 30993,
#  'orlando': 43109,
#  'bored': 11445,
#  'sad': 49569,
#  'whole': 61973,
#  'without': 62344,
#  'him': 27446,
#  'cheer': 14071,
#  'up': 59875,
#  'feeling': 22524,
#  'horrible': 27898,
#  'headache': 26821,
#  'feels': 22529,
#  'like': 34966,
#  'tension': 56305,
#  'bed': 9994,
#  'laying': 34345,
#  'low': 36022,
#  'myspace': 40475,
#  'mobile': 39213,
#  'acting': 5759,
#  'reeeaalll': 47694,
#  'dumb': 19975,
#  'right': 48547,
#  'grrrr': 25895,
#  'had': 26204,
#  'page': 43548,
#  'messages': 38175,
#  'checkin': 14049,
#  'dtanton': 19867,
#  'nah': 40620,
#  'iced': 28580,
#  'coffee': 15217,
#  'give': 24987,
#  'real': 47412,
#  'thing': 57068,
#  'katernz': 32431,
#  'yea': 63446,
#  'hope': 27854,
#  'morning': 39598,
#  'airport': 6406,
#  'again': 6143,
#  'especially': 21400,
#  'such': 54732,
#  'an': 7300,
#  'early': 20230,
#  'david': 17569,
#  'he': 26812,
#  'mad': 36479,
#  'at': 8556,
#  'getting': 24758,
#  '17': 3846,
#  'journey': 31752,
#  'usa': 59991,
#  '..peace': 929,
#  'out': 43211,
#  'ireland': 29673,
#  '6': 4762,
#  'btw': 12249,
#  'soo': 53122,
#  'bad': 9291,
#  'little': 35295,
#  'bit': 10743,
#  'nicer': 41337,
#  'outside': 43266,
#  'tho': 57149,
#  'bethyv': 10408,
#  'sorry': 53218,
#  'finally': 22800,
#  'heading': 26838,
#  'from': 23901,
#  'schreiber..': 50353,
#  'ugh..': 59437,
#  'tiring': 57613,
#  'http': 28116,
#  '//myloc.me/447l': 2010,
#  'midnight': 38442,
#  'drags': 19595,
#  'better': 10417,
#  'would': 62691,
#  'let': 34720,
#  'smoke': 52663,
#  'tires': 57612,
#  'tonight': 57981,
#  '#': 1,
#  'tweetdeck': 58926,
#  'use': 59997,
#  'mark': 37123,
#  'all': 6741,
#  'as': 8284,
#  'seen': 50696,
#  'then': 56839,
#  'clear': 14949,
#  'tweets': 58962,
#  'manage': 36838,
#  'columns': 15379,
#  'relog': 47933,
#  'l8r': 33824,
#  'they': 57037,
#  "'re": 226,
#  'any': 7778,
#  'clues': 15067,
#  'kimmy2006': 33118,
#  'kimmy': 33117,
#  'ru': 49263,
#  'awake': 8886,
#  'hurt': 28302,
#  'fuck': 23977,
#  'keep': 32663,
#  'absorbed': 5598,
#  'or': 43015,
#  'goin': 25219,
#  'mouth': 39740,
#  'wherever': 61872,
#  'its': 29867,
#  'normal': 41905,
#  'lips': 35175,
#  'man': 36827,
#  'sleepy': 52434,
#  'wish': 62297,
#  'time': 57458,
#  'nap': 40712,
#  'omgahitskasey': 42734,
#  'yeah': 63457,
#  'are': 8073,
#  'helping': 27132,
#  'cuz': 16902,
#  'love': 35912,
#  'infected': 29222,
#  'relationship': 47876,
#  'over': 43297,
#  '2legit2britt': 4218,
#  'know': 33418,
#  'hate': 26675,
#  'damn': 17202,
#  'rain': 47023,
#  'totally': 58156,
#  'cut': 16860,
#  'driving': 19752,
#  'lesson': 34713,
#  'short': 51643,
#  'falkonfly': 22168,
#  'ouchies': 43192,
#  'feel': 22521,
#  'soon': 53130,
#  'rocksmyworld': 48882,
#  'that': 56531,
#  'tweet': 58910,
#  'before': 10079,
#  'downstairs': 19537,
#  'twinklybee': 59062,
#  'having': 26730,
#  'complaint': 15523,
#  'record': 47603,
#  'help': 27125,
#  'term': 56331,
#  'restarts': 48222,
#  'though': 57194,
#  'yes': 63548,
#  'cologne': 15343,
#  'course': 16149,
#  'lol': 35576,
#  'plane': 45058,
#  'middle': 38428,
#  'seat': 50595,
#  'stuck': 54562,
#  'traffic': 58297,
#  '-__-': 700,
#  'typical': 59328,
#  'jakarta': 30206,
#  'the_real_shaq': 56594,
#  'sticks': 54269,
#  'stones': 54362,
#  'ur': 59941,
#  'bones': 11313,
#  'words': 62577,
#  'your': 63750,
#  'heart': 26879,
#  'clouds': 15044,
#  'f*cking': 21989,
#  'computer': 15570,
#  'negative': 40998,
#  'spiral': 53543,
#  'moment': 39330,
#  'working': 62609,
#  'both': 11512,
#  'jobs': 31337,
#  'tomorrow': 57930,
#  'matt_is': 37418,
#  'tonsillitis': 58011,
#  'goes': 25199,
#  'oesophagus': 42401,
#  'sore': 53201,
#  'throat': 57245,
#  'tired': 57594,
#  'weather': 61433,
#  'perth': 44439,
#  'aah': 5433,
#  'eu': 21479,
#  'queria': 46709,
#  'daily': 17121,
#  '10': 3572,
#  'brasil': 11715,
#  'faircakelondon': 22122,
#  'angel': 7457,
#  'food': 23369,
#  'cake': 12819,
#  'has': 26649,
#  'intrigued': 29538,
#  'creme': 16432,
#  'brulee': 12164,
#  'turned': 58816,
#  'quite': 46776,
#  'runny': 49361,
#  'domestic': 19272,
#  'diva': 18934,
#  'swimusicrazed': 55443,
#  'ipod': 29645,
#  'too': 58022,
#  'billyraycyrus': 10645,
#  'oi': 42580,
#  'tell': 56230,
#  'daughter': 17526,
#  'lower': 36031,
#  'ticket': 57350,
#  'prices': 45961,
#  'we': 61406,
#  'cant': 13058,
#  'afford': 6083,
#  'london': 35652,
#  'sister': 52162,
#  'cried': 16451,
#  'blocking': 11004,
#  'almost': 6871,
#  '2am': 4178,
#  'only': 42840,
#  'worse': 62665,
#  'metrostation_': 38228,
#  'metro': 38223,
#  'station': 54003,
#  'spain': 53352,
#  'nobody': 41729,
#  'knows': 33432,
#  'them': 56810,
#  'hey': 27245,
#  'lunch': 36204,
#  'crew': 16442,
#  'jakesherlock': 30216,
#  'robweir': 48829,
#  'mayerjoy': 37566,
#  'sitting': 52185,
#  'lake': 33969,
#  'looks': 35715,
#  'late': 34165,
#  '1000': 3596,
#  'following': 23334,
#  'follower': 23319,
#  'wrong': 62787,
#  'here': 27181,
#  'caught': 13499,
#  'bug': 12334,
#  'brother': 12108,
#  'really': 47454,
#  'killing': 33060,
#  'hacking': 26200,
#  'ass': 8462,
#  'off': 42406,
#  'many': 36970,
#  'h/w.i': 26145,
#  'unexpected': 59682,
#  'college': 15331,
#  'stu': 54551,
#  'busy': 12540,
#  'these': 56986,
#  'days': 17675,
#  'sleep': 52405,
#  '2h/day': 4203,
#  'mcgiff': 37656,
#  'guy': 26076,
#  'fawkes': 22419,
#  'does': 19203,
#  'make': 36694,
#  'yr': 63818,
#  'blood': 11060,
#  'boil': 11259,
#  'us': 59989,
#  'struggling': 54548,
#  'ends': 21043,
#  'head': 26816,
#  'kicked': 32978,
#  'win-win': 62203,
#  'stubbed': 54559,
#  'toe': 57823,
#  'intact': 29431,
#  'beach': 9826,
#  'awesome': 8915,
#  'night': 41471,
#  'class': 14889,
#  'tuesdayblues': 58752,
#  'adorable-ness': 5962,
#  'voice': 60772,
#  'paramoreeeeee': 43786,
#  'camp': 12953,
#  'ugh': 59435,
#  'wake': 61082,
#  'lost': 35827,
#  'house': 28001,
#  'hence': 27149,
#  'panicing': 43702,
#  'think': 57085,
#  'minolta': 38734,
#  'x700': 63012,
#  'makes': 36718,
#  'funny': 24092,
#  'noises': 41771,
#  'focus': 23280,
#  'readin': 47396,
#  'news': 41221,
#  'world': 62633,
#  'katie': 32471,
#  'price': 45953,
#  'big': 10546,
#  'hug.i': 28150,
#  'story': 54403,
#  'made': 36508,
#  'cry': 16614,
#  'martyjb123': 37258,
#  'telling': 56237,
#  'mom': 39320,
#  'call': 12868,
#  'drugs': 19807,
#  'kelsyc': 32752,
#  'taxi..': 55962,
#  'hubbs': 28126,
#  'puking': 46396,
#  'potty': 45641,
#  'panties': 43720,
#  'tshirt': 58692,
#  'ananyah': 7327,
#  'sis': 52148,
#  'sick': 51820,
#  'wife': 62074,
#  'good': 25284,
#  'uk': 59491,
#  'treatin': 58431,
#  'ya': 63294,
#  'sion71': 52107,
#  'ok': 42593,
#  'end': 21014,
#  'thoughts': 57204,
#  'way': 61356,
#  'hug': 28148,
#  'guys': 26085,
#  'wash': 61254,
#  'hair': 26294,
#  'science': 50364,
#  'test': 56392,
#  'darcy1968': 17413,
#  'thats': 56563,
#  'because': 9940,
#  'spelt': 53485,
#  'try': 58667,
#  'mrmackenzie': 39879,
#  '//twitpic.com/886qt': 3230,
#  '//': 1289,
#  'extremely': 21923,
#  'doo': 19376,
#  'lilmamamaiya': 35024,
#  'tha': 56466,
#  'cool': 15897,
#  'friends': 23836,
#  'grade': 25528,
#  'younger': 63736,
#  'age': 6160,
#  'visitbrighton': 60677,
#  'whatever': 61803,
#  "shweet'art": 51788,
#  'seeing': 50681,
#  'book': 11352,
#  'gone': 25264,
#  'followers': 23322,
#  '50': 4656,
#  '46': 4560,
#  'gorgeous': 25410,
#  'ive': 29968,
#  'garden': 24382,
#  'first': 22927,
#  'week..but': 61545,
#  'wo': 62399,
#  'punch-out': 46423,
#  'wii': 62092,
#  'until': 59851,
#  'next': 41249,
#  'friday': 23810,
#  'should': 51679,
#  'paid': 43566,
#  'faster': 22356,
#  'shipping': 51519,
#  'save': 50133,
#  'money': 39405,
#  'divatchic': 18943,
#  'y': 63277,
#  'follow': 23312,
#  'gurl': 26038,
#  'graduating': 25543,
#  'married': 37207,
#  'stop': 54374,
#  'expect': 21832,
#  'change': 13842,
#  'plans': 45079,
#  'fucking': 23992,
#  'insomnia': 29373,
#  'gotten': 25464,
#  'woahamber': 62405,
#  'either': 20562,
#  'sashaostrikoff': 50051,
#  'happened': 26510,
#  'school': 50322,
#  'lame': 34009,
#  'beautiful': 9908,
#  'spent': 53496,
#  'classroom': 14908,
#  'eocean': 21191,
#  'noooo': 41855,
#  'run': 49337,
#  '3.0': 4304,
#  'irritated': 29719,
#  'did': 18547,
#  'release': 47898,
#  'after': 6113,
#  'left': 34534,
#  'iphone': 29629,
#  'wtfami': 62810,
#  'tim': 57446,
#  'mgiraudofficial': 38269,
#  'sold': 52969,
#  'city': 14797,
#  'near': 40933,
#  'tooth': 58061,
#  'hurts': 28313,
#  'betty': 10425,
#  'crocker': 16511,
#  'frosting': 23920,
#  'sparkly': 53390,
#  'things': 57078,
#  'come': 15402,
#  'onnnnnnnn': 42853,
#  'sims': 52031,
#  'stand': 53889,
#  'fully': 24045,
#  'educated': 20426,
#  'corrected': 16013,
#  'assumptions': 8512,
#  'staycation': 54028,
#  'locals': 35520,
#  '//staycation.ky/': 2321,
#  'shame': 51127,
#  'wisdom': 62289,
#  'teeth': 56178,
#  'pulled': 46404,
#  'swollen': 55471,
#  'dtsn': 19875,
#  'amykate': 7277,
#  'nottingham': 41989,
#  'boat': 11185,
#  'sunk': 54951,
#  '15': 3808,
#  'seconds': 50626,
#  'ritah': 48639,
#  'cramming': 16284,
#  'much': 40097,
#  'okay': 42605,
#  'forever': 23461,
#  'ever': 21575,
#  'jb': 30586,
#  'dissapointed': 18883,
#  'danieleazar': 17308,
#  'couldnt': 16107,
#  'find': 22816,
#  'picture': 44785,
#  'jimmy': 31192,
#  'choo': 14454,
#  'pair': 43607,
#  'boooo': 11390,
#  'internets': 29490,
#  'broken': 12048,
#  'fixed': 22985,
#  'tues': 58748,
#  'amyftw': 7268,
#  'nope': 41879,
#  'ride': 48521,
#  'bailed': 9366,
#  'hahahah': 26247,
#  'wait..': 61064,
#  'season': 50588,
#  'hills': 27432,
#  'oneself': 42821,
#  'wow': 62705,
#  'hungry': 28257,
#  'feet': 22535,
#  'selenagomez': 50740,
#  'bye': 12647,
#  'selena': 50738,
#  'talk': 55746,
#  'were': 61707,
#  'our': 43200,
#  'orchestra': 43036,
#  'leader': 34407,
#  'due': 19942,
#  'commitments': 15462,
#  'annacharlene': 7579,
#  'three-pile-system': 57224,
#  'stuff': 54592,
#  'quot': 46789,
#  'take': 55703,
#  'might': 38471,
#  'neck': 40949,
#  'bust': 12533,
#  'always': 6968,
#  'dinner': 18687,
#  'later': 34179,
#  'lmfao': 35482,
#  'slept': 52450,
#  'ughhhhh': 59447,
#  'kno': 33400,
#  'where': 61865,
#  'went': 61698,
#  'itz': 29951,
#  'ova': 43292,
#  'gym': 26113,
#  'abs': 5582,
#  'tight': 57414,
#  'more': 39553,
#  'less': 34711,
#  'confirmed': 15669,
#  'africa': 6101,
#  'trip': 58535,
#  'maybe': 37560,
#  'biz': 10779,
#  'best': 10358,
#  'friend': 23824,
#  'xbenchyx': 63042,
#  'appreciates': 7951,
#  'sound': 53270,
#  'input': 29333,
#  'mic': 38314,
#  'jack': 30082,
#  'usb': 59995,
#  'webcam': 61457,
#  'checked': 14043,
#  'controls': 15841,
#  'im': 28908,
#  'kansas': 32292,
#  'royals': 49201,
#  'errors': 21344,
#  'runs': 49362,
#  'jaredparson': 30401,
#  'gon': 25259,
#  'na': 40572,
#  'violet': 60627,
#  'scared': 50248,
#  'jump': 31990,
#  'thunder': 57288,
#  'lightning': 34951,
#  'understand': 59645,
#  'people': 44306,
#  'mean': 37750,
#  'randydeluxe': 47162,
#  'same': 49769,
#  'problem': 46070,
#  'about': 5560,
#  '30': 4325,
#  'unfinished': 59689,
#  'games': 24345,
#  '24': 4094,
#  'fitness': 22962,
#  'baby': 9171,
#  'leaving': 34472,
#  't_t': 55623,
#  'longest': 35682,
#  'watched': 61284,
#  '65': 4829,
#  'years': 63480,
#  'ago': 6206,
#  'must': 40313,
#  'hell': 27075,
#  'need': 40961,
#  'mr.': 39812,
#  'president': 45887,
#  'musicislove210': 40288,
#  'reminds': 47971,
#  'ex': 21689,
#  'neighbor': 41014,
#  'mrs.': 39898,
#  'byrd': 12666,
#  'uhoh': 59479,
#  'anything': 7802,
#  'documentally': 19184,
#  'thesolster': 56995,
#  '//vimeo.com/5197032': 3297,
#  'hates': 26681,
#  'bills': 10637,
#  'needs': 40972,
#  'another': 7680,
#  'job': 31327,
#  'asap': 8287,
#  'rambodoc': 47100,
#  'alternative': 6939,
#  'propose': 46222,
#  'those': 57190,
#  'who': 61957,
#  'die': 18563,
#  'treatment': 58433,
#  'ozdemotan': 43434,
#  'betas': 10386,
#  'tabbycat6380': 55634,
#  'forecast': 23445,
#  'even': 21561,
#  'show': 51698,
#  'tuesday': 58750,
#  'afraid': 6098,
#  'pray': 45749,
#  'hurricane': 28293,
#  'faeriewitch1228': 22087,
#  'neda': 40956,
#  'young': 63730,
#  'woman': 62444,
#  'murdered': 40218,
#  'iran': 29662,
#  'saturday': 50096,
#  'by': 12645,
#  'authorities': 8776,
#  'sporttrainer300': 53629,
#  'fell': 22555,
#  'playing': 45126,
#  'touch': 58168,
#  'footy': 23420,
#  'op': 42948,
#  'dr': 19566,
#  'said': 49644,
#  'tore': 58105,
#  'ligaments': 34934,
#  'ankle': 7562,
#  'bekahferguson': 10127,
#  'wait': 61061,
#  'aww': 8974,
#  'black': 10820,
#  'died': 18567,
#  'mah': 36609,
#  'favorite': 22404,
#  'picnic': 44778,
#  'laundry': 34232,
#  'clothes': 15034,
#  'yourselves': 63775,
#  '..': 812,
#  '*no': 513,
#  'movement*': 39749,
#  'obviously': 42338,
#  'dont': 19358,
#  'order': 43045,
#  'poneee': 45401,
#  'sadly': 49599,
#  'attacker': 8617,
#  'homeless': 27738,
#  'that1who': 56539,
#  'down': 19511,
#  'system': 55552,
#  'ultimately': 59521,
#  'takes': 55717,
#  'someone': 53030,
#  'keeps': 32669,
#  'missing': 38896,
#  'o': 42248,
#  'club': 15056,
#  'thanks': 56503,
#  'photo': 44671,
#  'comments': 15452,
#  'facebook.com/peazybaby': 22047,
#  'myspace.com/peazybaby': 40480,
#  'anti': 7724,
#  'biotics': 10697,
#  'till': 57441,
#  'afternoo': 6120,
#  'doubles': 19463,
#  'suck..': 54737,
#  'paradise': 43772,
#  'goodbye': 25300,
#  'rest': 48216,
#  'peace': 44150,
#  'daddy': 17081,
#  'happy': 26531,
#  'fathers': 22377,
#  '26': 4131,
#  'suite': 54830,
#  '98': 5106,
#  'tease': 56095,
#  '20': 4010,
#  'y/o': 63284,
#  'contact': 15786,
#  'ripped': 48616,
#  'blind': 10964,
#  'butt': 12556,
#  'rezn': 48387,
#  'chipmunks': 14377,
#  'woulda': 62696,
#  '35': 4389,
#  'everyday': 21596,
#  'whitelight007': 61934,
#  'mounting': 39723,
#  'folders': 23301,
#  'locked': 35530,
#  'delete': 18058,
#  'add': 5863,
#  'clue': 15065,
#  'marks': 37162,
#  'themselves': 56836,
#  'masking': 37318,
#  'their': 56761,
#  'faces': 22055,
#  'beating': 9888,
#  'handcuffed': 26413,
#  'place': 45030,
#  'new': 41188,
#  'randstadrail': 47160,
#  'volume': 60796,
#  'announcement-speakers': 7654,
#  'high': 27355,
#  'ears': 20244,
#  'tmrw': 57709,
#  'slave': 52382,
#  'tummy': 58777,
#  'hurst': 28301,
#  'drama': 19605,
#  'being': 10121,
#  'terrified': 56360,
#  'italy': 29839,
#  '//tinyurl.com/dhdpne': 2380,
#  'ahh': 6272,
#  'mcdonalds': 37633,
#  'skin': 52283,
#  'frannleach': 23659,
#  'doing': 19233,
#  'elimination': 20670,
#  'diet..': 18580,
#  'recently': 47558,
#  'thinking': 57091,
#  'wheat': 61836,
#  'intolerance': 29530,
#  'soy': 53327,
#  'detroit': 18343,
#  'sports': 53626,
#  'cruel': 16566,
#  'intentions': 29455,
#  'every': 21591,
#  'fallen': 22172,
#  'counting': 16128,
#  'crows': 16551,
#  'song': 53078,
#  'says': 50188,
#  'alot': 6890,
#  'rgoodchild': 48396,
#  'clearheaded': 14952,
#  'enough': 21115,
#  'questions': 46725,
#  'cold': 15271,
#  'meds': 37827,
#  'sm9': 52557,
#  'gutted': 26066,
#  'holding': 27643,
#  '2c': 4182,
#  'if': 28690,
#  'won': 62457,
#  'buy': 12605,
#  'trip2c': 58537,
#  'manager': 36843,
#  '//twitpic.com/6ch72': 2907,
#  'watchin': 61291,
#  '13th': 3784,
#  'part': 43850,
#  'fuse': 24126,
#  'wit': 62320,
#  'sunburned': 54920,
#  '2day': 4190,
#  'miracle': 38762,
#  '1st': 3954,
#  'nd': 40920,
#  'burned': 12482,
#  'car': 13132,
#  'dent': 18183,
#  'stationary': 54006,
#  'white': 61926,
#  'paint': 43590,
#  'neighbours': 41019,
#  '*angry': 368,
#  'face*': 22040,
#  'danggitsdevin': 17286,
#  'hahar': 26264,
#  'whaaat': 61782,
#  'concert': 15601,
#  'youu': 63790,
#  'goiing': 25217,
#  'yourr': 63767,
#  'lucky': 36118,
#  'geht': 24578,
#  'ahar': 6259,
#  'myself': 40467,
#  'idk': 28654,
#  'fatty': 22386,
#  'b/c': 9095,
#  'mcdonald': 37632,
#  '2x': 4277,
#  'history': 27517,
#  'exam': 21701,
#  'starting': 53972,
#  'able': 5545,
#  ...}

# %%
# These will now contain for each row a list of unique integer number and
# its associated importance as calculated by TF-IDF.
train_x_tfidf = tfidf.transform(train_x)
test_x_tfidf = tfidf.transform(test_x)
print("Word vectorization is complete.")
print("\n- Tfidf vectorized format of training set: ")
print(train_x_tfidf)
print("\n- Tfidf vectorized format of testing set: ")
print(test_x_tfidf)
# Out:
# Word vectorization is complete.
#
# - Tfidf vectorized format of training set:
#   (0, 57773)	0.26580747568220714
#   (0, 57730)	0.14180698993600635
#   (0, 57365)	0.5782866189330201
#   (0, 41959)	0.3779166761922947
#   (0, 41940)	0.2364550845116838
#   (0, 26649)	0.305973011002048
#   (0, 24051)	0.3194201709904071
#   (0, 19139)	0.23204337669400973
#   (0, 12545)	0.2226532057026917
#   (0, 0)	0.2775291352807045
#   (1, 54978)	0.7377416662069001
#   (1, 39598)	0.49541412629591225
#   (1, 25284)	0.4005182088014637
#   (1, 0)	0.2233545204986727
#   (2, 47454)	0.28190893380499477
#   (2, 28116)	0.25724632004098474
#   (2, 26649)	0.30196139648961995
#   (2, 25662)	0.3070500417535348
#   (2, 23836)	0.35058715756898406
#   (2, 5137)	0.2268014633520632
#   (2, 2159)	0.6916687984078597
#   (2, 808)	0.12702474260388927
#   (3, 63704)	0.17617846021852218
#   (3, 56574)	0.14152510730204554
#   (3, 29723)	0.1815037154639709
#   :	:
#   (39998, 6005)	0.4371364615907571
#   (39998, 5174)	0.07537801778420658
#   (39998, 817)	0.1253158577502477
#   (39999, 62329)	0.10731163204113144
#   (39999, 61184)	0.13673157283166193
#   (39999, 58858)	0.19520999858476207
#   (39999, 57730)	0.06609329842451941
#   (39999, 56574)	0.06786964833205471
#   (39999, 51711)	0.20478939524010634
#   (39999, 49012)	0.19205018677696667
#   (39999, 47829)	0.31475165889283474
#   (39999, 46144)	0.2491780500307363
#   (39999, 44972)	0.3063059132845059
#   (39999, 43781)	0.3266552687596229
#   (39999, 42771)	0.09732391105360895
#   (39999, 28413)	0.05472463190935013
#   (39999, 26649)	0.14260767776773986
#   (39999, 19223)	0.2263179419231237
#   (39999, 18394)	0.3266552687596229
#   (39999, 9473)	0.2227000886353149
#   (39999, 7017)	0.13321813036943866
#   (39999, 6741)	0.11785216966754455
#   (39999, 5956)	0.2898767609809703
#   (39999, 5612)	0.3063059132845059
#   (39999, 808)	0.17997039130538237
#
# - Tfidf vectorized format of testing set:
#   (0, 61973)	0.23971087015806092
#   (0, 56531)	0.12050200411976034
#   (0, 56503)	0.17058354636899217
#   (0, 50434)	0.36243673296223317
#   (0, 42771)	0.11981482465280928
#   (0, 37031)	0.36902625964957136
#   (0, 35853)	0.3770911885167275
#   (0, 28158)	0.3770911885167275
#   (0, 25222)	0.15271643600876442
#   (0, 21594)	0.28653563207050237
#   (0, 10889)	0.4021431457557437
#   (0, 5328)	0.09339125434591355
#   (0, 5174)	0.19090012209102428
#   (0, 239)	0.11823242754382232
#   (0, 0)	0.07962132082810187
#   (1, 59875)	0.15679198940829778
#   (1, 58953)	0.2938573145703096
#   (1, 57085)	0.1881081949081376
#   (1, 57037)	0.18804348731890563
#   (1, 54592)	0.24307520732259805
#   (1, 47150)	0.3134019909072223
#   (1, 42771)	0.13267502711920698
#   (1, 40541)	0.1306675983878778
#   (1, 40382)	0.10916615567462079
#   (1, 35576)	0.17554016469403738
#   :	:
#   (9997, 8184)	0.3019182138409829
#   (9997, 5174)	0.08609277815288163
#   (9997, 808)	0.19984007141473306
#   (9998, 63704)	0.22118849320768524
#   (9998, 54085)	0.8551794999364222
#   (9998, 35912)	0.32644142754255273
#   (9998, 28413)	0.14326841727717934
#   (9998, 7349)	0.21371335811426279
#   (9998, 5174)	0.13531986695997902
#   (9998, 0)	0.16931911447127052
#   (9999, 57730)	0.10004833770327057
#   (9999, 57461)	0.44564973719074485
#   (9999, 50929)	0.49447247180042664
#   (9999, 45030)	0.29140029803617534
#   (9999, 40541)	0.14509442582964752
#   (9999, 36204)	0.2843856165461058
#   (9999, 27993)	0.28937481677728283
#   (9999, 25144)	0.1825721117239103
#   (9999, 23422)	0.13629419896044914
#   (9999, 12719)	0.20407620509870647
#   (9999, 11512)	0.29890805330976417
#   (9999, 8556)	0.16497951062932284
#   (9999, 7300)	0.21650730620588274
#   (9999, 5328)	0.11483324997167788
#   (9999, 5174)	0.07824316310713743

# %% [markdown]
# # STEP 8: TRAIN & TEST ML MODELS FOR PREDICTING SENTIMENT OF TWEETS

# %%
# --- STEP 8: USE ML ALGORITHMS TO PREDICT OUTCOME ---
print("\n********** ML ALGORITHMS **********\n")
print("- Classifier 1: Multinomial Naive Bayes")

# fit the training dataset on the NB classifier
print("|___ Fitting training dataset on the MNB classifier...")
model_MNB = naive_bayes.MultinomialNB()
start = timeit.default_timer()
model_MNB.fit(train_x_tfidf, train_y)
stop = timeit.default_timer()
print("|___ Training is complete. Total time: ", stop - start)

# predict the labels on validation dataset
print("|___ Making predictions...")
start = timeit.default_timer()
predictions_MNB = model_MNB.predict(test_x_tfidf)
stop = timeit.default_timer()
print("|___ Finished making predictions. Total time: ", stop - start)

# calculate effectiveness metrics
print("|___ Naive Bayes Accuracy Score -> ", accuracy_score(test_y, predictions_MNB)*100)
print(classification_report(test_y, predictions_MNB))
print("Confusion Matrix:\n", confusion_matrix(test_y, predictions_MNB))
# Out:
# ********** ML ALGORITHMS **********
#
# - Classifier 1: Multinomial Naive Bayes
# |___ Fitting training dataset on the MNB classifier...
# |___ Training is complete. Total time:  0.014184599999907732
# |___ Making predictions...
# |___ Finished making predictions. Total time:  0.002373400000124093
# |___ Naive Bayes Accuracy Score ->  75.11
#               precision    recall  f1-score   support
#
#            0       0.72      0.82      0.77      5058
#            1       0.79      0.68      0.73      4942
#
#     accuracy                           0.75     10000
#    macro avg       0.76      0.75      0.75     10000
# weighted avg       0.76      0.75      0.75     10000
#
# Confusion Matrix:
#  [[4161  897]
#  [1592 3350]]

# %%
# Classifier 2 - Algorithm - SVM
# fit the training dataset on the SVM classifier
print("\n- Classifier 2: Support Vector Machines (SVM)")
print("|___ Fitting training dataset on the SVM classifier...")
model_SVM = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
start = timeit.default_timer()
model_SVM.fit(train_x_tfidf, train_y)
stop = timeit.default_timer()
print("|___ Training is complete. Total time: ", stop-start)
# predict the labels on validation dataset
print("|___ Making predictions...")
start = timeit.default_timer()
predictions_SVM = model_SVM.predict(test_x_tfidf)
start = timeit.default_timer()
print("|___ Finished making predictions. Total time: ", stop-start)
# Use accuracy_score function to get the accuracy
print("|___ SVM Accuracy Score -> ", accuracy_score(test_y, predictions_SVM)*100)
print(classification_report(test_y, predictions_SVM))
print("Confusion Matrix:\n", confusion_matrix(test_y, predictions_SVM))
# Out:
# - Classifier 2: Support Vector Machines (SVM)
# |___ Fitting training dataset on the SVM classifier...
# |___ Training is complete. Total time:  363.12506180000014
# |___ Making predictions...
# |___ Finished making predictions. Total time:  -34.777232199999844
# |___ SVM Accuracy Score ->  77.64999999999999
#               precision    recall  f1-score   support
#
#            0       0.79      0.76      0.78      5058
#            1       0.76      0.79      0.78      4942
#
#     accuracy                           0.78     10000
#    macro avg       0.78      0.78      0.78     10000
# weighted avg       0.78      0.78      0.78     10000
#
# Confusion Matrix:
#  [[3856 1202]
#  [1033 3909]]

# %%
model_LR = LogisticRegression(C=1, max_iter=1000)
# fit the training dataset on the Logistic Regression classifier
print("\nFitting training dataset on the Logistic Regression classifier...")
start = timeit.default_timer()
model_LR.fit(train_x_tfidf, train_y)
stop = timeit.default_timer()
print("Training is complete. Total time: ", stop - start)
# predict the labels on validation dataset (i.e. test dataset)
print("Making predictions...")
start = timeit.default_timer()
predictions_LR = model_LR.predict(test_x_tfidf)
stop = timeit.default_timer()
print("- Finished making predictions! Total Time: ", stop - start)
print("- LR Accuracy Score for C=%s: %s" % (1, accuracy_score(test_y, predictions_LR)*100))
print(classification_report(test_y, predictions_LR))
print("Confusion Matrix:\n", confusion_matrix(test_y, predictions_LR))


prec = metrics.precision_score(test_y, predictions_LR, average='macro')
rec = metrics.recall_score(test_y, predictions_LR, average='macro')
f1 = metrics.f1_score(test_y, predictions_LR, average='macro')
print(prec)
print(rec)
print(f1)
# Out:
# Fitting training dataset on the Logistic Regression classifier...
# Training is complete. Total time:  0.8445051999999578
# Making predictions...
# - Finished making predictions! Total Time:  0.0010948999999982334
# - LR Accuracy Score for C=1: 77.36
#               precision    recall  f1-score   support
#
#            0       0.79      0.75      0.77      5058
#            1       0.76      0.79      0.78      4942
#
#     accuracy                           0.77     10000
#    macro avg       0.77      0.77      0.77     10000
# weighted avg       0.77      0.77      0.77     10000
#
# Confusion Matrix:
#  [[3810 1248]
#  [1016 3926]]
# 0.7741338270298863
# 0.7738386877338215
# 0.7735695315161608
