# %% [markdown]
# # STEP 1: IMPORT REQUIRED LIBRARIES

# %%
import pandas as pd
import numpy as np
import nltk
import timeit
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %% [markdown]
# # STEP 2: SET RANDOM SEED

# %%
# This is used to reproduce the same result every time if the script is kept consistent.
# Otherwise, each run will produce different results. The seed can be set to any number.
np.random.seed(500)

# %% [markdown]
# # STEP 3: LOAD IMDB MOVIE REVIEW DATASET

# %%
# STEP 3: ADD CORPUS
print("Loading data...")
dataset = pd.read_csv("Datasets/IMDB.csv", encoding='latin-1')
print("Data successfully loaded!")
print(dataset)
# positive sentiment = 0, negative sentiment = 1
# Out:
# Loading data...
# Data successfully loaded!
#                                                     text sentiment
# 0      Now, I won't deny that when I purchased this o...       neg
# 1      The saddest thing about this "tribute" is that...       neg
# 2      Last night I decided to watch the prequel or s...       neg
# 3      I have to admit that i liked the first half of...       neg
# 4      I was not impressed about this film especially...       neg
# ...                                                  ...       ...
# 49995  For one thing, he produced this movie. It has ...       neg
# 49996  The title comes from an alteration an adolesce...       pos
# 49997  Christopher Nolan's first film is a 'no budget...       pos
# 49998  The story is shortly about the faith-lacking b...       neg
# 49999  I found parts of this movie rather slow, espec...       pos
#
# [50000 rows x 2 columns]

# %% [markdown]
# # STEP 4: DATA PROCESSING

# %%
# Step 4a: Remove blank rows if any.
print("\nStart of Data Pre-processing...")
print("- Removing blanks...")
dataset['text'].dropna(inplace=True)
print("- Blanks removed.")
# Out:
# Start of Data Pre-processing...
# - Removing blanks...
# - Blanks removed.

# %%
# Step 4b : Change all the text to lower case. 
print("- Converting to lowercase...")
dataset['text'] = [entry.lower() for entry in dataset['text']]
print("- Converted to lowercase.")
# Out:
# - Converting to lowercase...
# - Converted to lowercase.

# %%
# Step 4c: Tokenization to divide each movie review into a set of words (unigrams)
print("- Starting tokenization...")
dataset['text'] = [word_tokenize(entry) for entry in dataset['text']]
print("- Tokenization is complete")
print(dataset['text'])
print("- End of data pre-processing.")
print("\n***** Current View of Corpus *****\n")
print(dataset)
# Out:
# - Starting tokenization...
# - Tokenization is complete
# 0        [now, ,, i, wo, n't, deny, that, when, i, purc...
# 1        [the, saddest, thing, about, this, ``, tribute...
# 2        [last, night, i, decided, to, watch, the, preq...
# 3        [i, have, to, admit, that, i, liked, the, firs...
# 4        [i, was, not, impressed, about, this, film, es...
#                                ...
# 49995    [for, one, thing, ,, he, produced, this, movie...
# 49996    [the, title, comes, from, an, alteration, an, ...
# 49997    [christopher, nolan, 's, first, film, is, a, '...
# 49998    [the, story, is, shortly, about, the, faith-la...
# 49999    [i, found, parts, of, this, movie, rather, slo...
# Name: text, Length: 50000, dtype: object
# - End of data pre-processing.
#
# ***** Current View of Corpus *****
#
#                                                     text sentiment
# 0      [now, ,, i, wo, n't, deny, that, when, i, purc...       neg
# 1      [the, saddest, thing, about, this, ``, tribute...       neg
# 2      [last, night, i, decided, to, watch, the, preq...       neg
# 3      [i, have, to, admit, that, i, liked, the, firs...       neg
# 4      [i, was, not, impressed, about, this, film, es...       neg
# ...                                                  ...       ...
# 49995  [for, one, thing, ,, he, produced, this, movie...       neg
# 49996  [the, title, comes, from, an, alteration, an, ...       pos
# 49997  [christopher, nolan, 's, first, film, is, a, '...       pos
# 49998  [the, story, is, shortly, about, the, faith-la...       neg
# 49999  [i, found, parts, of, this, movie, rather, slo...       pos
#
# [50000 rows x 2 columns]

# %% [markdown]
# # STEP 5: PREPARE TRAIN & TEST DATASETS

# %%
print("- Splitting dataset (80% train, 20% test)...")
train_x, test_x, train_y, test_y = model_selection.train_test_split(dataset['text'], dataset['sentiment'], test_size=0.2)
print("- Data splitting is complete.")
print(train_x)
print(train_y)
# Out:
# - Splitting dataset (80% train, 20% test)...
# - Data splitting is complete.
# 543      [i, have, read, all, of, the, love, come, soft...
# 25470    [i, was, in, my, mid, teens, when, i, saw, thi...
# 29798    [while, the, camerawork, was, certainly, ``, f...
# 28698    [if, you, are, looking, for, a, modern, film, ...
# 18438    [this, film, got, terrible, reviews, but, beca...
#                                ...
# 19389    [the, howling, ii, starts, as, it, means, to, ...
# 3790     [this, was, a, new, alltime, low, among, weste...
# 41233    [heart, of, darkness, was, terrible, ., the, n...
# 44865    [the, three, stooges, has, always, been, some,...
# 17335    [look, ,, i, 'm, reading, and, reading, this, ...
# Name: text, Length: 40000, dtype: object
# 543      neg
# 25470    pos
# 29798    pos
# 28698    pos
# 18438    pos
#         ...
# 19389    neg
# 3790     neg
# 41233    neg
# 44865    pos
# 17335    neg
# Name: sentiment, Length: 40000, dtype: object

# %% [markdown]
# # STEP 6: DATA ENCODING

# %%
print("- Encoding data if not already done (i.e. categorical data converted to numerical values)...\n")
Encoder = LabelEncoder()
print("Original Train_Y: ", train_y)
train_y = Encoder.fit_transform(train_y)
print("New Train_Y:      ", train_y)
print("Original Test_Y:  ", test_y)
test_y = Encoder.fit_transform(test_y)
print("New Test_Y:       ", test_y)
print("\n- Data encoding is complete.")
# Out:
# - Encoding data if not already done (i.e. categorical data converted to numerical values)...
#
# Original Train_Y:  543      neg
# 25470    pos
# 29798    pos
# 28698    pos
# 18438    pos
#         ...
# 19389    neg
# 3790     neg
# 41233    neg
# 44865    pos
# 17335    neg
# Name: sentiment, Length: 40000, dtype: object
# New Train_Y:       [0 1 1 ... 0 1 0]
# Original Test_Y:   26124    pos
# 8562     neg
# 43159    pos
# 41935    neg
# 8867     pos
#         ...
# 37047    pos
# 40066    pos
# 33888    neg
# 27835    pos
# 1304     neg
# Name: sentiment, Length: 10000, dtype: object
# New Test_Y:        [1 0 1 ... 0 1 0]
#
# - Data encoding is complete.

# %% [markdown]
# # STEP 7: TF-IDF Feature Vectorization

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

def dummy_fun(doc):
    return doc

tfidf = TfidfVectorizer(
    analyzer='word',
    tokenizer=dummy_fun,
    preprocessor=dummy_fun,
    token_pattern=None)

tfidf.fit(dataset['text'])
tfidf.vocabulary_
# Out:
# {'now': 107301,
#  ',': 6266,
#  'i': 77891,
#  'wo': 165187,
#  "n't": 103403,
#  'deny': 46722,
#  'that': 149932,
#  'when': 163791,
#  'purchased': 121533,
#  'this': 150626,
#  'off': 108441,
#  'ebay': 53177,
#  'had': 71132,
#  'high': 74533,
#  'expectations': 57748,
#  '.': 6986,
#  'was': 162198,
#  'an': 17111,
#  'incredible': 79600,
#  'out-of-print': 110584,
#  'work': 165654,
#  'from': 64521,
#  'the': 149994,
#  'master': 95659,
#  'of': 108413,
#  'comedy': 38656,
#  'so': 139617,
#  'enjoy': 55238,
#  'however': 76953,
#  'soon': 140426,
#  'to': 152004,
#  'be': 23800,
#  'disappointed': 48797,
#  'apologies': 18668,
#  'those': 150756,
#  'who': 164104,
#  'enjoyed': 55259,
#  'it': 82146,
#  'but': 31081,
#  'just': 84472,
#  'found': 63569,
#  'compleat': 39226,
#  'al': 15490,
#  'very': 160025,
#  'difficult': 48106,
#  'watch': 162325,
#  'got': 68881,
#  'a': 12489,
#  'few': 60617,
#  'smiles': 139097,
#  'sure': 146492,
#  'majority': 94006,
#  'funny': 65023,
#  'came': 31924,
#  'music': 102884,
#  'videos': 160340,
#  '(': 5393,
#  'which': 163837,
#  "'ve": 5114,
#  'on': 109158,
#  'dvd': 52589,
#  ')': 5394,
#  'and': 17262,
#  'rest': 126689,
#  'basically': 23413,
#  'filler': 60948,
#  'you': 167349,
#  'could': 41519,
#  'tell': 149220,
#  'not': 106934,
#  "'s": 4091,
#  'greatest': 69545,
#  'video': 160272,
#  'achievement': 13438,
#  'honor': 76033,
#  'goes': 68193,
#  'uhf': 155902,
#  'honestly': 75975,
#  'doubt': 50905,
#  'if': 78302,
#  'will': 164525,
#  'ever': 56702,
#  'make': 94019,
#  'jump': 84337,
#  "'re": 3888,
#  'ultra-hardcore': 156026,
#  'fan': 59178,
#  'have': 72866,
#  'own': 111721,
#  'everything': 56880,
#  'buy': 31206,
#  'tape': 148344,
#  'do': 49880,
#  'pay': 113604,
#  'too': 152441,
#  'much': 102208,
#  'for': 63014,
#  'saddest': 130111,
#  'thing': 150463,
#  'about': 12971,
#  '``': 12488,
#  'tribute': 154085,
#  "''": 8,
#  'is': 81945,
#  'almost': 16286,
#  'all': 15913,
#  'singers': 137518,
#  'including': 79472,
#  'otherwise': 110444,
#  'incredibly': 79608,
#  'talented': 148027,
#  'nick': 105246,
#  'cave': 33759,
#  'seem': 133301,
#  'missed': 99634,
#  'whole': 164139,
#  'point': 117015,
#  'where': 163802,
#  'cohen': 38103,
#  'intensity': 80943,
#  'lies': 90181,
#  ':': 12262,
#  'by': 31269,
#  'delivering': 46316,
#  'his': 75102,
#  'lines': 90712,
#  'in': 79180,
#  'tuneless': 154879,
#  'poise': 117101,
#  'transmits': 153584,
#  'full': 64791,
#  'extent': 58102,
#  'poetry': 116985,
#  'irony': 81853,
#  'all-round': 15993,
#  'humanity': 77251,
#  'laughter': 88726,
#  'tears': 148834,
#  'one.': 109442,
#  '<': 12272,
#  'br': 28750,
#  '/': 7879,
#  '>': 12311,
#  'see': 133237,
#  'some': 140181,
#  'these': 150347,
#  'singer': 137499,
#  'upstarts': 158672,
#  'convoluted': 40763,
#  'suffering': 145531,
#  'faces': 58690,
#  'launch': 88741,
#  'their': 150080,
#  'pathetic': 113370,
#  'squeals': 142227,
#  'patent': 113344,
#  'effort': 53642,
#  'scream': 132472,
#  "'m": 2916,
#  '!': 2,
#  'true': 154532,
#  'pain': 112126,
#  'same': 130542,
#  'feeling': 60186,
#  'many': 94863,
#  'probably': 119867,
#  'listening': 90937,
#  'horrendous': 76323,
#  'operatic': 109744,
#  'versions': 159994,
#  'simple': 137352,
#  'songs': 140364,
#  'such': 145425,
#  'as': 19887,
#  'lennon': 89565,
#  'imagine': 78646,
#  'nothing': 107155,
#  'simply': 137388,
#  'gets': 66940,
#  'close': 37389,
#  'simplicity': 137374,
#  'directness': 48584,
#  'original': 110149,
#  'there': 150283,
#  'form': 63303,
#  'art': 19672,
#  'does': 50111,
#  'need': 104454,
#  'embellishments': 54462,
#  'cast': 33326,
#  'street': 144309,
#  'looking': 91801,
#  'like': 90449,
#  'tasteless': 148526,
#  'make-up': 94035,
#  'sex': 134847,
#  'sale.': 130377,
#  'myself': 103209,
#  'through': 151065,
#  'pitiful': 116068,
#  'tributes': 154090,
#  'awful': 21427,
#  'reinterpretations': 125509,
#  'them': 150102,
#  'entirely': 55542,
#  'lacking': 87747,
#  'truth': 154632,
#  'told': 152206,
#  'several': 134792,
#  'sounded': 140727,
#  'they': 150375,
#  'been': 24255,
#  'recruited': 124807,
#  'at': 20426,
#  'asylum': 20417,
#  'talent': 148019,
#  'show': 136488,
#  'doing': 50245,
#  'letting': 89868,
#  'sing': 137478,
#  'material': 95819,
#  'really': 124303,
#  'other': 110409,
#  'way': 162553,
#  'around': 19536,
#  'may': 96102,
#  'friends': 64367,
#  'or': 109923,
#  'daughter': 44946,
#  'he': 73051,
#  'become': 24145,
#  'tender-hearted': 149385,
#  'mood': 100760,
#  'gift': 67195,
#  'bad': 22153,
#  'did': 47947,
#  'stay': 143009,
#  'family.': 59146,
#  'fortunately': 63463,
#  'only': 109530,
#  'end': 54886,
#  'himself': 74931,
#  'performed': 114416,
#  'majestic': 93983,
#  'tower': 153071,
#  'song': 140343,
#  'even': 56647,
#  'flower': 62529,
#  'spoiled': 141766,
#  'totally': 152877,
#  'incongruous': 79531,
#  'background': 22054,
#  'u2': 155733,
#  'carrying': 33084,
#  'expression': 58037,
#  'bored': 28154,
#  'kids': 85847,
#  'visit': 160869,
#  'poor': 117543,
#  'grandpa': 69254,
#  'nursing': 107615,
#  'home.': 75799,
#  'sad': 130087,
#  'sadder': 130110,
#  'truly': 154576,
#  'love': 92185,
#  'last': 88453,
#  'night': 105382,
#  'decided': 45642,
#  'prequel': 119258,
#  'shall': 135263,
#  'say': 131319,
#  'called': 31810,
#  'carlito': 32873,
#  '-': 6297,
#  'rise': 127922,
#  'power': 118438,
#  '2005': 10076,
#  'went': 163402,
#  'straight': 144094,
#  '...': 6994,
#  'no': 105715,
#  'wonder': 165381,
#  '..it': 7119,
#  'completely': 39243,
#  'mean': 96687,
#  's': 129865,
#  '%': 5,
#  '&': 6,
#  'ks': 87261,
#  'waist': 161617,
#  'time': 151490,
#  'watching': 162377,
#  'think': 150511,
#  'would': 165954,
#  'pure': 121542,
#  'writing': 166240,
#  'understand': 157010,
#  'how': 76926,
#  'de': 45189,
#  'palma': 112309,
#  'agreed': 15053,
#  'producing': 120036,
#  'sh': 135059,
#  '#': 3,
#  't-fest': 147622,
#  'movie': 101623,
#  '.except': 7483,
#  'one': 109301,
#  'fact': 58728,
#  'tip': 151804,
#  'my': 103159,
#  'hat': 72723,
#  'jay': 83094,
#  'hernandez': 74155,
#  'plays': 116528,
#  'young': 167393,
#  'brigante': 29424,
#  'reminded': 125872,
#  'me': 96615,
#  'niro': 105631,
#  'into': 81387,
#  'shoes': 136155,
#  'brando': 28953,
#  'portray': 117883,
#  'don': 50407,
#  'corleone': 41113,
#  'godfather': 68132,
#  'ii': 78376,
#  'difference': 48073,
#  'amazing': 16687,
#  'oscar': 110295,
#  'well': 163045,
#  'has': 72644,
#  'guts': 70778,
#  'trying': 154668,
#  'pacino': 111986,
#  'him': 74876,
#  'playing': 116510,
#  'film': 60965,
#  'anymore': 18456,
#  'after': 14745,
#  'watched': 162362,
#  '$': 4,
#  'ty': 155550,
#  'sat': 131014,
#  'down': 50994,
#  'carlitos': 32874,
#  'get': 66907,
#  'taste': 148514,
#  'out': 110534,
#  'mouth': 101564,
#  'admit': 14235,
#  'liked': 90472,
#  'first': 61640,
#  'half': 71376,
#  'sleepers': 138540,
#  'looked': 91794,
#  'good': 68435,
#  'acting': 13605,
#  'better': 25294,
#  'story': 143925,
#  'childhood': 35602,
#  'revenge': 127060,
#  'interesting': 81086,
#  'moving': 101974,
#  'superior': 146238,
#  'hollywood': 75640,
#  'mentioned': 97519,
#  'far': 59400,
#  'least': 89107,
#  'latest': 88560,
#  '20': 9990,
#  'comments': 38919,
#  'courtroom': 41815,
#  'scenes': 131701,
#  'brat': 29007,
#  'pittâ´s': 116092,
#  'character': 34629,
#  'followed': 62837,
#  'plan': 116259,
#  'rescue': 126441,
#  'two': 155417,
#  'are': 19207,
#  'rightly': 127722,
#  'accused': 13395,
#  'murder': 102720,
#  'felt': 60325,
#  'cheated': 35074,
#  'insulted': 80825,
#  'intelligence': 80899,
#  'warning': 162123,
#  'spoilers': 141791,
#  'why': 164234,
#  'anyone': 18464,
#  'accept': 13223,
#  'false': 59038,
#  'alibi': 15785,
#  'witnessed': 165110,
#  'priest': 119571,
#  '?': 12312,
#  'guys': 70833,
#  'with': 165043,
#  'shouldnâ´t': 136460,
#  'during': 52484,
#  'investigation': 81587,
#  'amnesia': 16974,
#  'were': 163421,
#  'judge': 84209,
#  'member': 97297,
#  'jury': 84466,
#  'believe': 24619,
#  'wise': 164916,
#  'give': 67578,
#  'motif': 101382,
#  'murderers': 102750,
#  'away': 21385,
#  'am': 16595,
#  'sorry': 140583,
#  'weak': 162664,
#  'angers': 17477,
#  'great': 69502,
#  'potential': 118313,
#  '4/10': 10914,
#  'impressed': 79065,
#  'especially': 56195,
#  'cinema': 36402,
#  'family': 59122,
#  'faith': 58927,
#  'certificate': 34176,
#  'rated': 123443,
#  '12a': 8721,
#  'here': 74060,
#  'uk': 155924,
#  'dismay': 49265,
#  'embarrassing': 54438,
#  'sexual': 134968,
#  'jokes': 83897,
#  'problem': 119888,
#  'adult': 14347,
#  'children': 35616,
#  'times': 151651,
#  'crude': 43169,
#  'fart': 59582,
#  'getting': 66947,
#  'hit': 75181,
#  'groin': 69967,
#  'etc': 56360,
#  'most': 101264,
#  'part': 112988,
#  'funny.': 65040,
#  'premise': 119187,
#  'calvin': 31883,
#  'sims': 137402,
#  '2inch': 10422,
#  'midget': 98422,
#  'jail': 82756,
#  'steals': 143063,
#  'giant': 67135,
#  'sized': 137905,
#  'diamond': 47806,
#  'then': 150177,
#  'forced': 63070,
#  'put': 121699,
#  'womens': 165369,
#  'handbag': 71923,
#  'sees': 133362,
#  'passing': 113212,
#  'abandoned': 12757,
#  'baby': 21878,
#  'house': 76818,
#  'can': 32121,
#  'back.': 22016,
#  'up': 158474,
#  'until': 158345,
#  'output': 110807,
#  'wayans': 162603,
#  'brothers': 29875,
#  'certainly': 34169,
#  'taking': 147983,
#  'biscuit.': 26072,
#  'bit': 26102,
#  'advice': 14463,
#  'wait': 161627,
#  'till': 151452,
#  'comes': 38739,
#  'tv': 155135,
#  'cable': 31506,
#  'odd': 108321,
#  'couple': 41738,
#  'wonderful': 165395,
#  'comic': 38765,
#  'one-liners': 109360,
#  'entire': 55539,
#  'world': 165756,
#  'seems': 133314,
#  'knows': 86720,
#  'neurotic': 104890,
#  'neat-freak': 104356,
#  'felix': 60276,
#  'ungar': 157432,
#  'obnoxious': 108037,
#  'slob': 138726,
#  'madison': 93590,
#  'paring': 112845,
#  'mismatched': 99561,
#  'roommates': 128848,
#  'created': 42385,
#  'successful': 145392,
#  'series': 134518,
#  'countless': 41675,
#  'anywhere': 18512,
#  'near': 104233,
#  'imitations.': 78726,
#  'apartment': 18564,
#  'sloppy': 138776,
#  'habits': 71070,
#  'says': 131355,
#  'wants': 161950,
#  'food': 62900,
#  'poker': 117126,
#  'player': 116483,
#  'buddies': 30232,
#  'asks': 20070,
#  'what': 163655,
#  'ya': 166696,
#  'brown': 29903,
#  'sandwiches': 130728,
#  'green': 69589,
#  'either': 53896,
#  'new': 104968,
#  'cheese': 35167,
#  'old': 108957,
#  'meat': 96775,
#  'also': 16418,
#  'line': 90665,
#  'refrigerator': 125214,
#  'order': 110012,
#  'weeks': 162874,
#  'saw': 131271,
#  'milk': 98690,
#  'standing': 142632,
#  'bottle': 28377,
#  'question': 122215,
#  'walter': 161843,
#  'matthau': 95960,
#  'joy': 84112,
#  'screen': 132505,
#  'jack': 82598,
#  'klugman': 86496,
#  'version': 159977,
#  'series.': 134523,
#  'lemmon': 89496,
#  'makes': 94064,
#  'honest': 75961,
#  'role': 128541,
#  'depressing': 46858,
#  'down-trodden': 51033,
#  'becomes': 24152,
#  'more': 100954,
#  'annoying': 17791,
#  'than': 149890,
#  'comical': 38793,
#  'tony': 152437,
#  'randall': 123134,
#  'performance': 114377,
#  'brought': 29890,
#  'kind': 86090,
#  'humor': 77324,
#  'warmth': 162104,
#  'sensitivity': 134259,
#  'portrayal': 117886,
#  'lacks': 87752,
#  'unger': 157435,
#  'obviously': 108167,
#  'related': 125595,
#  'specific': 141234,
#  'situations': 137806,
#  'annoyance': 17783,
#  'needed': 104459,
#  'storyline': 144012,
#  'note': 107124,
#  'different': 48081,
#  'spelling': 141379,
#  'never': 104919,
#  'happy': 72217,
#  'fun': 64900,
#  'roommate': 128847,
#  'drives': 51702,
#  'wall': 161765,
#  'time.': 151572,
#  'still': 143493,
#  'moments': 100303,
#  'withstand': 165093,
#  'test': 149723,
#  'famous': 59171,
#  'meatloaf': 96792,
#  'fight': 60834,
#  'examples': 57315,
#  'little': 91035,
#  'notes': 107145,
#  'pillow': 115746,
#  'remembered': 125852,
#  'forever': 63216,
#  'darker': 44777,
#  'sides': 136989,
#  'over': 110929,
#  'top': 152568,
#  'crying': 43289,
#  'bawling': 23712,
#  'scene': 131647,
#  'involving': 81672,
#  'linguine': 90747,
#  'dinner': 48398,
#  'although': 16497,
#  'lightened': 90379,
#  'comical.': 38796,
#  'perhaps': 114436,
#  'enough': 55324,
#  'lighter': 90382,
#  'side': 136923,
#  'characters': 34718,
#  'made': 93509,
#  'memorable': 97329,
#  'beginning': 24404,
#  'minutes': 99229,
#  'boring': 28195,
#  'issue': 82120,
#  'occurs': 108248,
#  'conversation': 40699,
#  'pidgeon': 115580,
#  'sisters': 137731,
#  'ending': 54981,
#  'predictable': 119031,
#  'pat': 113317,
#  'care': 32701,
#  'compassion': 39138,
#  'each': 52872,
#  'result': 126774,
#  'leads': 89025,
#  'lot': 92037,
#  'depression': 46862,
#  'anger': 17470,
#  'rather': 123455,
#  'unless': 157728,
#  'described': 47034,
#  'above': 12990,
#  'appears': 18773,
#  'monotone': 100571,
#  'persona': 114657,
#  'brings': 29529,
#  'enhances': 55221,
#  'embraces': 54492,
#  'between': 25356,
#  'characters.': 34725,
#  'took': 152505,
#  '1970': 9571,
#  'best': 25193,
#  'hitting': 75280,
#  'cylinders': 43962,
#  'dianne': 47822,
#  'keaton': 85280,
#  'her': 74001,
#  'any': 18432,
#  'tom': 152259,
#  'everett': 56818,
#  'scott': 132370,
#  'always': 16552,
#  'underrated': 156987,
#  'should': 136430,
#  'star': 142697,
#  'complaint': 39219,
#  'aspect': 20096,
#  'screenplay': 132558,
#  'none': 106624,
#  'acknowledged': 13493,
#  'dead': 45223,
#  'person': 114646,
#  'neither': 104607,
#  'mother': 101326,
#  'played': 116473,
#  'she': 135562,
#  'breaks': 29150,
#  'promise': 120302,
#  'reveal': 127021,
#  'sleeping': 138544,
#  'commentators': 38910,
#  'said': 130252,
#  'political': 117248,
#  'agenda': 14905,
#  'baffling': 22329,
#  'politics': 117290,
#  'sucker': 145457,
#  'romance': 128674,
#  'qualify': 121961,
#  'plot': 116690,
#  'nailed': 103587,
#  'before': 24334,
#  'credits': 42486,
#  'dialog': 47746,
#  'development': 47487,
#  'suggest': 145595,
#  'investing': 81600,
#  'your': 167435,
#  'hour': 76792,
#  'elsehere': 54324,
#  'rush': 129664,
#  'rent': 126037,
#  'serendipity': 134473,
#  'third': 150561,
#  'fast-paced': 59675,
#  'sexy': 135002,
#  'spectacular': 141262,
#  'cagney': 31634,
#  'terrific': 149607,
#  'blondel': 26835,
#  'charms': 34876,
#  'wit': 164992,
#  'energy': 55077,
#  'obvious': 108160,
#  'pre-censorship': 118682,
#  'innuendo': 80485,
#  'script': 132636,
#  'costumes': 41454,
#  'touch': 152917,
#  'bikinis': 25775,
#  'holds': 75549,
#  'barred': 23235,
#  'everyone': 56872,
#  'john': 83815,
#  'garfield': 65926,
#  'though': 150766,
#  'matter': 95942,
#  'whether': 163823,
#  'short': 136284,
#  'prop': 120368,
#  'frame': 63763,
#  'find': 61383,
#  'big': 25635,
#  'seen': 133319,
#  'turner': 155023,
#  'classics': 36905,
#  'accident': 13261,
#  'sit': 137741,
#  'back': 21964,
#  'ride': 127541,
#  'proverb': 120667,
#  'book': 27896,
#  'cover': 41856,
#  'coined': 38159,
#  'fail': 58832,
#  'look': 91760,
#  'beneath': 24842,
#  'surface': 146520,
#  'viewed': 160424,
#  'artwork': 19856,
#  'king': 86148,
#  'ants': 18388,
#  'instantly': 80719,
#  'thought': 150786,
#  'horror': 76373,
#  'arcane': 19095,
#  'imagery': 78610,
#  'proudly': 120649,
#  'displayed': 49404,
#  'spoke': 141820,
#  'dark': 44750,
#  'vision': 160857,
#  'synopsis': 147499,
#  'promised': 120305,
#  'betrayal': 25274,
#  'retribution': 126927,
#  'instead': 80723,
#  'discovered': 49009,
#  'less': 89705,
#  'under': 156763,
#  'average': 21236,
#  'rock.': 128331,
#  'features': 60096,
#  'chris': 36030,
#  'l.': 87582,
#  'mckenna': 96470,
#  'sean': 132920,
#  'crawley': 42306,
#  'guy': 70808,
#  'ready': 124174,
#  'name': 103657,
#  'means': 96740,
#  'except': 57370,
#  'someone': 140210,
#  'once': 109242,
#  'feel': 60171,
#  'sympathy': 147414,
#  'downright': 51085,
#  'unlikable': 157733,
#  'daniel': 44628,
#  'baldwin': 22538,
#  'ray': 123649,
#  'mathews': 95870,
#  'turns': 155040,
#  'uninspired': 157576,
#  'worst': 165906,
#  'utterly': 158989,
#  'laughable': 88691,
#  'dialogue': 47764,
#  'recite': 124626,
#  'throw': 151094,
#  'kari': 84994,
#  'wuhrer': 166365,
#  'grieving': 69781,
#  'widow': 164329,
#  'apparently': 18727,
#  'unconditional': 156647,
#  'trust': 154614,
#  'esp': 56182,
#  'homeless': 75820,
#  'common': 39010,
#  'sense': 134211,
#  'george': 66735,
#  'wendt': 163397,
#  'duke': 52181,
#  'sober': 139740,
#  'norm': 106783,
#  'cheers': 35163,
#  'hallucination': 71695,
#  'sequences': 134419,
#  'source': 140779,
#  'images': 78616,
#  'delves': 46388,
#  'further': 65128,
#  'prefers': 119112,
#  'bombard': 27647,
#  'unmotivated': 157827,
#  'unlikely': 157744,
#  'event': 56678,
#  'oh': 108737,
#  'guessing': 70358,
#  'writers': 166222,
#  'read': 124134,
#  'dickens': 47894,
#  'novel': 107253,
#  'david': 44998,
#  'copperfield': 40979,
#  'based': 23359,
#  'another': 17833,
#  'poorly': 117562,
#  'written': 166257,
#  'possibly': 118007,
#  'adaptation': 14006,
#  'likely': 90481,
#  'anything': 18473,
#  'else': 54309,
#  'randomly': 123149,
#  'discarded': 48903,
#  'pages': 112103,
#  'shuffled': 136738,
#  'along': 16339,
#  'random': 123143,
#  'eighth': 53825,
#  'grade': 69087,
#  'nephew': 104725,
#  'english': 55158,
#  'class': 36864,
#  'received': 124554,
#  'failing': 58844,
#  'casting': 33390,
#  'joke': 83881,
#  'e.g.': 52840,
#  'richards': 127458,
#  'kramer': 87086,
#  'micawber': 98108,
#  'direction': 48555,
#  'poorly-': 117563,
#  'delivered': 46311,
#  'punch': 121377,
#  'beyond': 25422,
#  'possible': 117998,
#  'ham': 71745,
#  'complete': 39234,
#  'ogre': 108732,
#  'hunch-back': 77395,
#  'expecting': 57758,
#  'being': 24513,
#  'pursued': 121639,
#  'angry': 17524,
#  'pitch-fork': 116042,
#  'torch': 152685,
#  'wielding': 164347,
#  'mob': 99938,
#  'villagers': 160552,
#  'uriah': 158750,
#  'clown': 37506,
#  'figure': 60887,
#  'mr.': 102032,
#  'murdstone': 102770,
#  'evoked': 56980,
#  'terror': 149642,
#  'muppet': 102697,
#  'vampire': 159312,
#  'sesame': 134637,
#  'actor': 13802,
#  'older': 109013,
#  'actually': 13930,
#  'woman': 165295,
#  'case': 33213,
#  'perpetually': 114570,
#  'wished': 164959,
#  'mirror': 99293,
#  'pretty': 119459,
#  'fancied': 59220,
#  'quite': 122400,
#  'indeed': 79661,
#  'scarcely': 131480,
#  'convince': 40746,
#  'us': 158798,
#  'quill': 122339,
#  'pen': 114009,
#  'while': 163852,
#  'we': 162654,
#  'subject': 145124,
#  'gross': 70003,
#  'inaccuracies': 79276,
#  'perpetrated': 114563,
#  'half-wit': 71583,
#  'producers': 120026,
#  'embarrassment': 54442,
#  'unnecessary': 157850,
#  'shots': 136418,
#  'somewhere': 140276,
#  '18': 9036,
#  '21': 10179,
#  'years': 166998,
#  'forties': 63439,
#  'transgression': 153539,
#  'choose': 35914,
#  'invented': 81544,
#  'showdown': 136547,
#  'courted': 41794,
#  'wife': 164367,
#  'switzerland': 147235,
#  'preceded': 118927,
#  'course': 41768,
#  'death': 45361,
#  'second': 133048,
#  'send': 134150,
#  'heep': 73571,
#  'guillotine': 70447,
#  'deliver': 46305,
#  'sidney': 137023,
#  'carton': 33130,
#  'words': 165633,
#  'things': 150494,
#  'worse': 165869,
#  'might': 98494,
#  'better.': 25316,
#  'literally': 90979,
#  'thousands': 150841,
#  'small': 138972,
#  'large': 88321,
#  'sins': 137623,
#  'against': 14854,
#  'literature': 90991,
#  'throughout': 151085,
#  'miscarriage': 99372,
#  'watches': 162372,
#  'runs': 129624,
#  'risk': 127939,
#  'severe': 134797,
#  'permanent': 114521,
#  'damage': 44425,
#  'aspects': 20100,
#  'sensibility': 134246,
#  'huge': 77116,
#  'sandler': 130693,
#  'please': 116577,
#  'bother': 28354,
#  'extremely': 58241,
#  'disappointing': 48810,
#  'bought': 28419,
#  '7.99': 11671,
#  'assuming': 20304,
#  'halfway': 71608,
#  'decent': 45612,
#  'since': 137446,
#  'man': 94372,
#  'because': 24109,
#  'assumed': 20301,
#  'women': 165348,
#  'naked': 103628,
#  'judging': 84225,
#  'r-rating': 122488,
#  'scantily-clad': 131462,
#  'career': 32723,
#  'snl': 139450,
#  'days': 45117,
#  'wrong': 166270,
#  'home': 75768,
#  'movies': 101894,
#  'cheesy': 35206,
#  'reminisce': 125884,
#  ...}

# %%
# These will now contain for each row a list of unique integer number and
# its associated importance as calculated by TF-IDF.
train_x_tfidf = tfidf.transform(train_x)
test_x_tfidf = tfidf.transform(test_x)
print("Word vectorization is complete.")
print("\n- Tfidf vectorized format of training set: ")
print(train_x_tfidf)
print("\n- Tfidf vectorized format of testing set: ")
print(test_x_tfidf)
# Out:
# Word vectorization is complete.
#
# - Tfidf vectorized format of training set:
#   (0, 167122)	0.07964176797888631
#   (0, 164139)	0.06528437786785464
#   (0, 163045)	0.04575004974678714
#   (0, 162198)	0.14276749576037187
#   (0, 160869)	0.1135938381204398
#   (0, 158852)	0.07541086601202374
#   (0, 155383)	0.11711980458250261
#   (0, 152441)	0.05034290237328452
#   (0, 152004)	0.021256661923826824
#   (0, 150626)	0.044002503983757615
#   (0, 150463)	0.058200880542624706
#   (0, 150375)	0.07361558164657424
#   (0, 150102)	0.050353847855037694
#   (0, 149994)	0.28248077266901955
#   (0, 149932)	0.19406297749430287
#   (0, 143925)	0.04469554372737391
#   (0, 139967)	0.17647442783051487
#   (0, 139617)	0.03558095640065858
#   (0, 130542)	0.06043055114736108
#   (0, 130087)	0.17524974561519838
#   (0, 129114)	0.1199896207643265
#   (0, 124134)	0.15101381709540648
#   (0, 123460)	0.08965372589547715
#   (0, 117015)	0.06627073253433186
#   (0, 115920)	0.1585533672640553
#   :	:
#   (39999, 14745)	0.030053981547781904
#   (39999, 13321)	0.055856684739244405
#   (39999, 12971)	0.0795207736623066
#   (39999, 12715)	0.05423760515785831
#   (39999, 12489)	0.06866520687101386
#   (39999, 12488)	0.010703836010284122
#   (39999, 12312)	0.013382984165693787
#   (39999, 12311)	0.12984810283701814
#   (39999, 12272)	0.12991171594610224
#   (39999, 12262)	0.014944556881071233
#   (39999, 11468)	0.03469786115112042
#   (39999, 10436)	0.3357687671723543
#   (39999, 9036)	0.03906525646113183
#   (39999, 8984)	0.03897964656180684
#   (39999, 7879)	0.129686394335505
#   (39999, 7642)	0.05460349880075174
#   (39999, 7405)	0.06470661065606166
#   (39999, 6994)	0.18039460718014158
#   (39999, 6986)	0.03665467991839379
#   (39999, 6266)	0.16315608238592696
#   (39999, 4091)	0.008111429359167558
#   (39999, 2916)	0.08840008536800545
#   (39999, 8)	0.010707237929302157
#   (39999, 5)	0.03147975083138995
#   (39999, 2)	0.1490827843542225
#
# - Tfidf vectorized format of testing set:
#   (0, 166046)	0.13013658929836439
#   (0, 165043)	0.026967586152284426
#   (0, 164525)	0.047277741768986865
#   (0, 163421)	0.045221436642602746
#   (0, 163045)	0.04522000385065059
#   (0, 162377)	0.05724291653862225
#   (0, 162198)	0.08466806148316991
#   (0, 160025)	0.04094270646607766
#   (0, 158907)	0.08700903549353767
#   (0, 158474)	0.04181684441008616
#   (0, 157647)	0.13446887972754074
#   (0, 152149)	0.14187889925525257
#   (0, 152004)	0.0630311664818417
#   (0, 150626)	0.04349270461117965
#   (0, 150080)	0.0451442141060964
#   (0, 149994)	0.17949088156615903
#   (0, 149932)	0.07193048399508054
#   (0, 149918)	0.100126297765919
#   (0, 148357)	0.1412778197937266
#   (0, 140181)	0.07752176597420411
#   (0, 134518)	0.14330422200403303
#   (0, 133237)	0.08452412755414224
#   (0, 133114)	0.19021436199919228
#   (0, 131701)	0.056713119603041706
#   (0, 131223)	0.0845362672545715
#   :	:
#   (9999, 20426)	0.015569522846942368
#   (9999, 20300)	0.053781867664002656
#   (9999, 19887)	0.013521238441416733
#   (9999, 19112)	0.07856445574613737
#   (9999, 18752)	0.04808758510281223
#   (9999, 17262)	0.11590704538010806
#   (9999, 17111)	0.032145229560205955
#   (9999, 16391)	0.037701464063826844
#   (9999, 15913)	0.04693451797927211
#   (9999, 15305)	0.058233854759717214
#   (9999, 14745)	0.023235519285795172
#   (9999, 12971)	0.035131194411710066
#   (9999, 12489)	0.1351302083715387
#   (9999, 12488)	0.01655083122038459
#   (9999, 12311)	0.11473024556151401
#   (9999, 12272)	0.11478645237136868
#   (9999, 11124)	0.04160709946488795
#   (9999, 7879)	0.11458736433581543
#   (9999, 6986)	0.1322472286659895
#   (9999, 6306)	0.1316686521606156
#   (9999, 6266)	0.19406190019196837
#   (9999, 5394)	0.06074982007399773
#   (9999, 5393)	0.06109112405053229
#   (9999, 4091)	0.012542316432227463
#   (9999, 8)	0.01655609144554488

# %% [markdown]
# # STEP 8: TRAIN & TEST ML MODELS FOR PREDICTING SENTIMENT OF IMDB MOVIE REVIEWS

# %%
# --- STEP 8: USE ML ALGORITHMS TO PREDICT OUTCOME ---
print("\n********** ML ALGORITHMS **********\n")
print("- Classifier 1: Multinomial Naive Bayes")
# fit the training dataset on the NB classifier
print("|___ Fitting training dataset on the MNB classifier...")
model_MNB = naive_bayes.MultinomialNB()
start = timeit.default_timer()
model_MNB.fit(train_x_tfidf, train_y)
stop = timeit.default_timer()
print("|___ Training is complete. Total time: ", stop - start)
# predict the labels on validation dataset
print("|___ Making predictions...")
start = timeit.default_timer()
predictions_MNB = model_MNB.predict(test_x_tfidf)
stop = timeit.default_timer()
print("|___ Finished making predictions. Total time: ", stop - start)
# Use accuracy_score function to get the accuracy
# ground truth: news_test.target; predicted labels: predicted
print("|___ Naive Bayes Accuracy Score -> ", accuracy_score(test_y, predictions_MNB)*100)
print(classification_report(test_y, predictions_MNB))
print("Confusion Matrix:\n", confusion_matrix(test_y, predictions_MNB))
# Out:
# ********** ML ALGORITHMS **********
#
# - Classifier 1: Multinomial Naive Bayes
# |___ Fitting training dataset on the MNB classifier...
# |___ Training is complete. Total time:  0.05070279999995364
# |___ Making predictions...
# |___ Finished making predictions. Total time:  0.009250099999917438
# |___ Naive Bayes Accuracy Score ->  85.96000000000001
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86      5015
#            1       0.88      0.83      0.86      4985
#
#     accuracy                           0.86     10000
#    macro avg       0.86      0.86      0.86     10000
# weighted avg       0.86      0.86      0.86     10000
#
# Confusion Matrix:
#  [[4434  581]
#  [ 823 4162]]

# %%
# Classifier 2 - Algorithm - SVM
# fit the training dataset on the SVM classifier
print("\n- Classifier 2: Support Vector Machines (SVM)")
print("|___ Fitting training dataset on the SVM classifier...")
model_SVM = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
start = timeit.default_timer()
model_SVM.fit(train_x_tfidf, train_y)
stop = timeit.default_timer()
print("|___ Training is complete. Total time: ", stop-start)
# predict the labels on validation dataset
print("|___ Making predictions...")
start = timeit.default_timer()
predictions_SVM = model_SVM.predict(test_x_tfidf)
stop = timeit.default_timer()
print("|___ Finished making predictions. Total time: ", stop-start)
# Use accuracy_score function to get the accuracy
print("|___ SVM Accuracy Score -> ", accuracy_score(test_y, predictions_SVM)*100)
print(classification_report(test_y, predictions_SVM))
print("Confusion Matrix:\n", confusion_matrix(test_y, predictions_SVM))
# Out:
# - Classifier 2: Support Vector Machines (SVM)
# |___ Fitting training dataset on the SVM classifier...
# |___ Training is complete. Total time:  1515.4763630999998
# |___ Making predictions...
# |___ Finished making predictions. Total time:  178.54507049999984
# |___ SVM Accuracy Score ->  90.62
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91      5015
#            1       0.90      0.92      0.91      4985
#
#     accuracy                           0.91     10000
#    macro avg       0.91      0.91      0.91     10000
# weighted avg       0.91      0.91      0.91     10000
#
# Confusion Matrix:
#  [[4491  524]
#  [ 414 4571]]

# %%
for c in [0.01, 0.05, 0.25, 0.5, 1]:
    model_LR = LogisticRegression(C=c, max_iter=1000)
    # fit the training dataset on the Logistic Regression classifier
    print("\nFitting training dataset on the Logistic Regression classifier...")
    start = timeit.default_timer()
    model_LR.fit(train_x_tfidf, train_y)
    stop = timeit.default_timer()
    print("Training is complete. Total time: ", stop - start)
    # predict the labels on validation dataset (i.e. test dataset)
    print("Making predictions...")
    start = timeit.default_timer()
    predictions_LR = model_LR.predict(test_x_tfidf)
    stop = timeit.default_timer()
    print("- Finished making predictions! Total Time: ", stop - start)
    print("- LR Accuracy Score for C=%s: %s" % (c, accuracy_score(test_y, predictions_LR)*100))
    print(classification_report(test_y, predictions_LR))
    print("Confusion Matrix:\n", confusion_matrix(test_y, predictions_LR))
# Out:
# Fitting training dataset on the Logistic Regression classifier...
# Training is complete. Total time:  0.9530605999998443
# Making predictions...
# - Finished making predictions! Total Time:  0.006024400000114838
# - LR Accuracy Score for C=0.01: 77.88000000000001
#               precision    recall  f1-score   support
#
#            0       0.80      0.74      0.77      5015
#            1       0.76      0.81      0.79      4985
#
#     accuracy                           0.78     10000
#    macro avg       0.78      0.78      0.78     10000
# weighted avg       0.78      0.78      0.78     10000
#
# Confusion Matrix:
#  [[3726 1289]
#  [ 923 4062]]
#
# Fitting training dataset on the Logistic Regression classifier...
# Training is complete. Total time:  1.0883217000000514
# Making predictions...
# - Finished making predictions! Total Time:  0.004285400000298978
# - LR Accuracy Score for C=0.05: 83.41
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83      5015
#            1       0.82      0.86      0.84      4985
#
#     accuracy                           0.83     10000
#    macro avg       0.84      0.83      0.83     10000
# weighted avg       0.84      0.83      0.83     10000
#
# Confusion Matrix:
#  [[4042  973]
#  [ 686 4299]]
#
# Fitting training dataset on the Logistic Regression classifier...
# Training is complete. Total time:  2.2601478999999927
# Making predictions...
# - Finished making predictions! Total Time:  0.006169199999931152
# - LR Accuracy Score for C=0.25: 87.33
#               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.87      5015
#            1       0.86      0.89      0.87      4985
#
#     accuracy                           0.87     10000
#    macro avg       0.87      0.87      0.87     10000
# weighted avg       0.87      0.87      0.87     10000
#
# Confusion Matrix:
#  [[4306  709]
#  [ 558 4427]]
#
# Fitting training dataset on the Logistic Regression classifier...
# Training is complete. Total time:  2.700102599999809
# Making predictions...
# - Finished making predictions! Total Time:  0.0051845999996658065
# - LR Accuracy Score for C=0.5: 88.53
#               precision    recall  f1-score   support
#
#            0       0.90      0.87      0.88      5015
#            1       0.88      0.90      0.89      4985
#
#     accuracy                           0.89     10000
#    macro avg       0.89      0.89      0.89     10000
# weighted avg       0.89      0.89      0.89     10000
#
# Confusion Matrix:
#  [[4379  636]
#  [ 511 4474]]
#
# Fitting training dataset on the Logistic Regression classifier...
# Training is complete. Total time:  4.426552500000071
# Making predictions...
# - Finished making predictions! Total Time:  0.004664800000227842
# - LR Accuracy Score for C=1: 89.47
#               precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89      5015
#            1       0.89      0.91      0.90      4985
#
#     accuracy                           0.89     10000
#    macro avg       0.89      0.89      0.89     10000
# weighted avg       0.89      0.89      0.89     10000
#
# Confusion Matrix:
#  [[4435  580]
#  [ 473 4512]]
